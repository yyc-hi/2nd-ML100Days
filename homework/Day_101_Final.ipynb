# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import keras
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score
# Out:
# Using TensorFlow backend.

# %%
DATA_DIR = 'data/kaggle_dogcat'
CATEGORIES = ['cat', 'dog']
IMG_SCALE = 5
IMG_W = IMG_H = 32 * IMG_SCALE
IMG_CHANNELS = 3
IMG_SIZE = (IMG_W, IMG_H)

data = []
for c in CATEGORIES:
    c_dir = c + 's'
    for f in os.listdir(os.path.join(DATA_DIR, 'train', c_dir)):
        data.append((os.path.join(c_dir, f), c))
df = pd.DataFrame(data, columns=['filename', 'category'])
df['category'].value_counts()
# Out:
# cat    2000
# dog    2000
# Name: category, dtype: int64

# %%
df_test = pd.DataFrame({'filename': sorted(os.listdir(os.path.join(DATA_DIR, 'test')))})
df_test.count()
# Out:
# filename    400
# dtype: int64

# %%
df_train, df_val = train_test_split(df, test_size=0.1, random_state=1)
df_train.reset_index(drop=True)
df_val.reset_index(drop=True)
print('df_train:\n', df_train['category'].value_counts())
print('df_val:\n', df_val['category'].value_counts())
# Out:
# df_train:
#  dog    1807
# cat    1793
# Name: category, dtype: int64
# df_val:
#  cat    207
# dog    193
# Name: category, dtype: int64

# %%
def plot_train_history(exps, epochs):
    color_bar = ["r", "g", "b", "y", "m", "k"]
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
    ax1.set_title('Loss')
    ax1.set_xticks(np.arange(1, epochs, 1))
    ax1.set_yticks(np.arange(0, 1, 0.1))
    
    ax2.set_title('Acc')
    ax2.set_xticks(np.arange(1, epochs, 1))
    
    for i, (exp, history) in enumerate(exps.items()):
        c = color_bar[i]
        ax1.plot(history.history['loss'], color=c, label=exp)
        ax1.plot(history.history['val_loss'], color=c, label=exp, linestyle='--')
        ax2.plot(history.history['acc'], color=c, label=exp)
        ax2.plot(history.history['val_acc'], color=c, label=exp, linestyle='--')

    legend = plt.legend(loc='best', shadow=True)
    plt.tight_layout()
    plt.show()

def make_validation(y_valid, y_pred, category_index):
    auc_score = roc_auc_score(y_true=y_valid, y_score=y_pred[:, category_index])
    acc = accuracy_score(y_true=y_valid, y_pred=y_pred.argmax(axis=1))
    print("Validation AUC: {:.3f}, Accuracy: {:.3f}".format(auc_score, acc))

# %%
def get_train_gen(df_train, batch_size):
    train_datagen = ImageDataGenerator(
        rotation_range=15,
        rescale=1./255,
        shear_range=0.1,
        zoom_range=0.2,
        horizontal_flip=True,
        width_shift_range=0.1,
        height_shift_range=0.1
    )
    train_gen = train_datagen.flow_from_dataframe(
        df_train, 
        os.path.join(DATA_DIR, 'train'), 
        x_col='filename',
        y_col='category',
        target_size=IMG_SIZE,
        class_mode='categorical',
        classes=CATEGORIES,
        batch_size=batch_size
    )
    return train_gen

def get_val_gen(df_val, batch_size):
    val_datagen = ImageDataGenerator(rescale=1./255)
    val_gen = val_datagen.flow_from_dataframe(
        df_val, 
        os.path.join(DATA_DIR, 'train'), 
        x_col='filename',
        y_col='category',
        target_size=IMG_SIZE,
        class_mode='categorical',
        classes=CATEGORIES,
        batch_size=batch_size
    )
    return val_gen

def get_test_gen(df_test, batch_size):
    test_datagen = ImageDataGenerator(rescale=1./255)
    test_gen = test_datagen.flow_from_dataframe(
        df_test, 
        os.path.join(DATA_DIR, 'test'), 
        x_col='filename',
        y_col=None,
        class_mode=None,
        target_size=IMG_SIZE,
        batch_size=batch_size,
        shuffle=False
    )
    return test_gen

# %%
def train(EPOCHS, ALPHA, H5FILE, BATCH_SIZE):
    keras.backend.clear_session() # 把舊的 Graph 清掉
    base_model = MobileNetV2(
        input_shape=(IMG_W, IMG_H, IMG_CHANNELS),
        alpha=ALPHA,
        include_top=False
    )
    
    x = base_model.output
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    preds = Dense(2, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=preds)
    
    model.compile(loss='categorical_crossentropy',
#                   optimizer=Adam(),
                  optimizer='rmsprop',
                  metrics=['accuracy'])

    callbacks = [
        ModelCheckpoint(H5FILE, monitor='val_acc', verbose=1, save_best_only=True),
#         EarlyStopping(patience=10, verbose=1),
        ReduceLROnPlateau(monitor='val_acc', patience=2, verbose=1, factor=0.5, min_lr=1e-5)
    #     EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1),
    #     ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-7, verbose=1)
    ]

    history = model.fit_generator(
        get_train_gen(df_train, BATCH_SIZE),
        steps_per_epoch=df_train.shape[0]//BATCH_SIZE,
        validation_data=get_val_gen(df_val, BATCH_SIZE),
        validation_steps=df_val.shape[0]//BATCH_SIZE,
        callbacks=callbacks,
        epochs=EPOCHS,
        verbose=1
    )
    return history

# %%
BATCH_SIZE = 64
PREDICT_CATEGORY = 'cat'
EPOCHS_LIST = [50]
ALPHA_LIST = [0.35, 0.5, 1.0]

H5FILE_FORMAT = 'Day_101_Final_{}_%s.h5'.format(IMG_SCALE)
OUTFILE_FORMAT = 'Day_101_Final_{}_%s.csv'.format(IMG_SCALE)

# %%
from itertools import product

train_gen = get_train_gen(df_train, BATCH_SIZE)
label_map = dict(train_gen.class_indices.items())
print(label_map)

exps = {}
for EPOCHS, ALPHA in product(EPOCHS_LIST, ALPHA_LIST):
    exp = 'e%03d_a%03d' % (EPOCHS, int(ALPHA * 100))
    print('### %s:' % exp)
    H5FILE = H5FILE_FORMAT % exp
    exps[exp] = train(EPOCHS, ALPHA, H5FILE, BATCH_SIZE)
    print('###end %s:' % exp)
    print()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0819 01:56:27.934561 139994835445568 deprecation_wrapper.py:119] From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0819 01:56:27.935229 139994835445568 deprecation_wrapper.py:119] From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0819 01:56:27.948756 139994835445568 deprecation_wrapper.py:119] From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0819 01:56:27.949554 139994835445568 deprecation_wrapper.py:119] From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0819 01:56:27.952719 139994835445568 deprecation_wrapper.py:119] From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0819 01:56:28.008556 139994835445568 deprecation_wrapper.py:119] From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# Found 3600 images belonging to 2 classes.
# {'cat': 0, 'dog': 1}
# ### e050_a035:
# Downloading data from https://github.com/JonathanCMitchell/mobilenet_v2_keras/releases/download/v1.1/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.35_160_no_top.h5
# 2023424/2019640 [==============================] - 2s 1us/step
# W0819 01:56:36.665470 139994835445568 deprecation.py:506] From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0819 01:56:36.685787 139994835445568 deprecation_wrapper.py:119] From /opt/conda/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0819 01:56:36.824525 139994835445568 deprecation.py:323] From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Found 3600 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# Epoch 1/50
# 56/56 [==============================] - 66s 1s/step - loss: 0.4594 - acc: 0.8619 - val_loss: 0.3900 - val_acc: 0.9167
#
# Epoch 00001: val_acc improved from -inf to 0.91667, saving model to Day_101_Final_5_e050_a035.h5
# Epoch 2/50
# 56/56 [==============================] - 56s 1s/step - loss: 0.2401 - acc: 0.9029 - val_loss: 0.3961 - val_acc: 0.9226
#
# Epoch 00002: val_acc improved from 0.91667 to 0.92262, saving model to Day_101_Final_5_e050_a035.h5
# Epoch 3/50
# 56/56 [==============================] - 56s 998ms/step - loss: 0.1842 - acc: 0.9291 - val_loss: 0.4545 - val_acc: 0.9196
#
# Epoch 00003: val_acc did not improve from 0.92262
# Epoch 4/50
# 56/56 [==============================] - 55s 991ms/step - loss: 0.1639 - acc: 0.9341 - val_loss: 0.6153 - val_acc: 0.9018
#
# Epoch 00004: val_acc did not improve from 0.92262
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 5/50
# 56/56 [==============================] - 56s 992ms/step - loss: 0.1217 - acc: 0.9498 - val_loss: 0.2613 - val_acc: 0.9345
#
# Epoch 00005: val_acc improved from 0.92262 to 0.93452, saving model to Day_101_Final_5_e050_a035.h5
# Epoch 6/50
# 56/56 [==============================] - 56s 993ms/step - loss: 0.0911 - acc: 0.9660 - val_loss: 0.3069 - val_acc: 0.9167
#
# Epoch 00006: val_acc did not improve from 0.93452
# Epoch 7/50
# 56/56 [==============================] - 56s 995ms/step - loss: 0.0844 - acc: 0.9660 - val_loss: 0.2885 - val_acc: 0.9315
#
# Epoch 00007: val_acc did not improve from 0.93452
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 8/50
# 56/56 [==============================] - 56s 998ms/step - loss: 0.0634 - acc: 0.9785 - val_loss: 0.2839 - val_acc: 0.9245
#
# Epoch 00008: val_acc did not improve from 0.93452
# Epoch 9/50
# 56/56 [==============================] - 55s 986ms/step - loss: 0.0619 - acc: 0.9774 - val_loss: 0.2694 - val_acc: 0.9226
#
# Epoch 00009: val_acc did not improve from 0.93452
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 10/50
# 56/56 [==============================] - 55s 990ms/step - loss: 0.0479 - acc: 0.9810 - val_loss: 0.1519 - val_acc: 0.9554
#
# Epoch 00010: val_acc improved from 0.93452 to 0.95536, saving model to Day_101_Final_5_e050_a035.h5
# Epoch 11/50
# 56/56 [==============================] - 55s 988ms/step - loss: 0.0405 - acc: 0.9860 - val_loss: 0.1787 - val_acc: 0.9494
#
# Epoch 00011: val_acc did not improve from 0.95536
# Epoch 12/50
# 56/56 [==============================] - 56s 995ms/step - loss: 0.0396 - acc: 0.9847 - val_loss: 0.2405 - val_acc: 0.9435
#
# Epoch 00012: val_acc did not improve from 0.95536
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 13/50
# 56/56 [==============================] - 55s 991ms/step - loss: 0.0519 - acc: 0.9839 - val_loss: 0.1458 - val_acc: 0.9524
#
# Epoch 00013: val_acc did not improve from 0.95536
# Epoch 14/50
# 56/56 [==============================] - 55s 988ms/step - loss: 0.0287 - acc: 0.9897 - val_loss: 0.2046 - val_acc: 0.9464
#
# Epoch 00014: val_acc did not improve from 0.95536
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 15/50
# 56/56 [==============================] - 55s 985ms/step - loss: 0.0230 - acc: 0.9919 - val_loss: 0.2033 - val_acc: 0.9427
#
# Epoch 00015: val_acc did not improve from 0.95536
# Epoch 16/50
# 56/56 [==============================] - 55s 985ms/step - loss: 0.0251 - acc: 0.9922 - val_loss: 0.1660 - val_acc: 0.9494
#
# Epoch 00016: val_acc did not improve from 0.95536
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 17/50
# 56/56 [==============================] - 55s 987ms/step - loss: 0.0238 - acc: 0.9922 - val_loss: 0.2141 - val_acc: 0.9405
#
# Epoch 00017: val_acc did not improve from 0.95536
# Epoch 18/50
# 56/56 [==============================] - 55s 983ms/step - loss: 0.0204 - acc: 0.9911 - val_loss: 0.1822 - val_acc: 0.9613
#
# Epoch 00018: val_acc improved from 0.95536 to 0.96131, saving model to Day_101_Final_5_e050_a035.h5
# Epoch 19/50
# 56/56 [==============================] - 55s 983ms/step - loss: 0.0405 - acc: 0.9872 - val_loss: 0.2419 - val_acc: 0.9286
#
# Epoch 00019: val_acc did not improve from 0.96131
# Epoch 20/50
# 56/56 [==============================] - 56s 993ms/step - loss: 0.0371 - acc: 0.9903 - val_loss: 0.2064 - val_acc: 0.9524
#
# Epoch 00020: val_acc did not improve from 0.96131
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 21/50
# 56/56 [==============================] - 55s 987ms/step - loss: 0.0188 - acc: 0.9933 - val_loss: 0.1566 - val_acc: 0.9524
#
# Epoch 00021: val_acc did not improve from 0.96131
# Epoch 22/50
# 56/56 [==============================] - 55s 990ms/step - loss: 0.0200 - acc: 0.9930 - val_loss: 0.2044 - val_acc: 0.9453
#
# Epoch 00022: val_acc did not improve from 0.96131
# Epoch 23/50
# 56/56 [==============================] - 55s 986ms/step - loss: 0.0150 - acc: 0.9953 - val_loss: 0.1632 - val_acc: 0.9554
#
# Epoch 00023: val_acc did not improve from 0.96131
# Epoch 24/50
# 56/56 [==============================] - 56s 991ms/step - loss: 0.0283 - acc: 0.9897 - val_loss: 0.2329 - val_acc: 0.9315
#
# Epoch 00024: val_acc did not improve from 0.96131
# Epoch 25/50
# 56/56 [==============================] - 55s 989ms/step - loss: 0.0387 - acc: 0.9866 - val_loss: 0.2267 - val_acc: 0.9375
#
# Epoch 00025: val_acc did not improve from 0.96131
# Epoch 26/50
# 56/56 [==============================] - 56s 993ms/step - loss: 0.0201 - acc: 0.9930 - val_loss: 0.1499 - val_acc: 0.9583
#
# Epoch 00026: val_acc did not improve from 0.96131
# Epoch 27/50
# 56/56 [==============================] - 56s 992ms/step - loss: 0.0309 - acc: 0.9886 - val_loss: 0.2093 - val_acc: 0.9405
#
# Epoch 00027: val_acc did not improve from 0.96131
# Epoch 28/50
# 56/56 [==============================] - 55s 988ms/step - loss: 0.0270 - acc: 0.9900 - val_loss: 0.2287 - val_acc: 0.9464
#
# Epoch 00028: val_acc did not improve from 0.96131
# Epoch 29/50
# 56/56 [==============================] - 56s 992ms/step - loss: 0.0231 - acc: 0.9922 - val_loss: 0.2077 - val_acc: 0.9479
#
# Epoch 00029: val_acc did not improve from 0.96131
# Epoch 30/50
# 56/56 [==============================] - 56s 994ms/step - loss: 0.0341 - acc: 0.9880 - val_loss: 0.1961 - val_acc: 0.9405
#
# Epoch 00030: val_acc did not improve from 0.96131
# Epoch 31/50
# 56/56 [==============================] - 56s 991ms/step - loss: 0.0336 - acc: 0.9866 - val_loss: 0.2098 - val_acc: 0.9494
#
# Epoch 00031: val_acc did not improve from 0.96131
# Epoch 32/50
# 56/56 [==============================] - 56s 996ms/step - loss: 0.0185 - acc: 0.9933 - val_loss: 0.2013 - val_acc: 0.9405
#
# Epoch 00032: val_acc did not improve from 0.96131
# Epoch 33/50
# 56/56 [==============================] - 56s 994ms/step - loss: 0.0209 - acc: 0.9911 - val_loss: 0.2300 - val_acc: 0.9464
#
# Epoch 00033: val_acc did not improve from 0.96131
# Epoch 34/50
# 56/56 [==============================] - 56s 998ms/step - loss: 0.0187 - acc: 0.9950 - val_loss: 0.1851 - val_acc: 0.9494
#
# Epoch 00034: val_acc did not improve from 0.96131
# Epoch 35/50
# 56/56 [==============================] - 56s 992ms/step - loss: 0.0201 - acc: 0.9928 - val_loss: 0.1871 - val_acc: 0.9464
#
# Epoch 00035: val_acc did not improve from 0.96131
# Epoch 36/50
# 56/56 [==============================] - 56s 993ms/step - loss: 0.0181 - acc: 0.9936 - val_loss: 0.2122 - val_acc: 0.9427
#
# Epoch 00036: val_acc did not improve from 0.96131
# Epoch 37/50
# 56/56 [==============================] - 55s 991ms/step - loss: 0.0195 - acc: 0.9933 - val_loss: 0.2034 - val_acc: 0.9464
#
# Epoch 00037: val_acc did not improve from 0.96131
# Epoch 38/50
# 56/56 [==============================] - 55s 990ms/step - loss: 0.0351 - acc: 0.9889 - val_loss: 0.1768 - val_acc: 0.9554
#
# Epoch 00038: val_acc did not improve from 0.96131
# Epoch 39/50
# 56/56 [==============================] - 55s 982ms/step - loss: 0.0169 - acc: 0.9936 - val_loss: 0.2434 - val_acc: 0.9405
#
# Epoch 00039: val_acc did not improve from 0.96131
# Epoch 40/50
# 56/56 [==============================] - 55s 984ms/step - loss: 0.0191 - acc: 0.9925 - val_loss: 0.1884 - val_acc: 0.9405
# Epoch 00040: val_acc did not improve from 0.96131
# Epoch 41/50
# 56/56 [==============================] - 56s 991ms/step - loss: 0.0261 - acc: 0.9930 - val_loss: 0.2021 - val_acc: 0.9464
#
# Epoch 00041: val_acc did not improve from 0.96131
# Epoch 42/50
# 56/56 [==============================] - 55s 991ms/step - loss: 0.0190 - acc: 0.9942 - val_loss: 0.1979 - val_acc: 0.9464
#
# Epoch 00042: val_acc did not improve from 0.96131
# Epoch 43/50
# 56/56 [==============================] - 56s 994ms/step - loss: 0.0307 - acc: 0.9897 - val_loss: 0.2091 - val_acc: 0.9427
#
# Epoch 00043: val_acc did not improve from 0.96131
# Epoch 44/50
# 56/56 [==============================] - 55s 988ms/step - loss: 0.0160 - acc: 0.9953 - val_loss: 0.1487 - val_acc: 0.9554
#
# Epoch 00044: val_acc did not improve from 0.96131
# Epoch 45/50
# 56/56 [==============================] - 55s 982ms/step - loss: 0.0162 - acc: 0.9933 - val_loss: 0.2334 - val_acc: 0.9315
#
# Epoch 00045: val_acc did not improve from 0.96131
# Epoch 46/50
# 56/56 [==============================] - 55s 983ms/step - loss: 0.0236 - acc: 0.9919 - val_loss: 0.2088 - val_acc: 0.9405
#
# Epoch 00046: val_acc did not improve from 0.96131
# Epoch 47/50
# 56/56 [==============================] - 55s 987ms/step - loss: 0.0178 - acc: 0.9933 - val_loss: 0.2359 - val_acc: 0.9494
#
# Epoch 00047: val_acc did not improve from 0.96131
# Epoch 48/50
# 56/56 [==============================] - 55s 988ms/step - loss: 0.0172 - acc: 0.9933 - val_loss: 0.2135 - val_acc: 0.9435
#
# Epoch 00048: val_acc did not improve from 0.96131
# Epoch 49/50
# 56/56 [==============================] - 55s 988ms/step - loss: 0.0165 - acc: 0.9936 - val_loss: 0.1781 - val_acc: 0.9524
#
# Epoch 00049: val_acc did not improve from 0.96131
# Epoch 50/50
# 56/56 [==============================] - 56s 993ms/step - loss: 0.0270 - acc: 0.9925 - val_loss: 0.2201 - val_acc: 0.9427
#
# Epoch 00050: val_acc did not improve from 0.96131
# ###end e050_a035:
#
# ### e050_a050:
# Downloading data from https://github.com/JonathanCMitchell/mobilenet_v2_keras/releases/download/v1.1/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.5_160_no_top.h5
# 3203072/3201480 [==============================] - 2s 1us/step
# Found 3600 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# Epoch 1/50
# 56/56 [==============================] - 78s 1s/step - loss: 0.4391 - acc: 0.8703 - val_loss: 0.3764 - val_acc: 0.9089
#
# Epoch 00001: val_acc improved from -inf to 0.90885, saving model to Day_101_Final_5_e050_a050.h5
# Epoch 2/50
# 56/56 [==============================] - 71s 1s/step - loss: 0.2325 - acc: 0.9082 - val_loss: 0.3048 - val_acc: 0.9405
#
# Epoch 00002: val_acc improved from 0.90885 to 0.94048, saving model to Day_101_Final_5_e050_a050.h5
# Epoch 3/50
# 56/56 [==============================] - 70s 1s/step - loss: 0.2020 - acc: 0.9233 - val_loss: 0.4232 - val_acc: 0.8929
#
# Epoch 00003: val_acc did not improve from 0.94048
# Epoch 4/50
# 56/56 [==============================] - 70s 1s/step - loss: 0.1794 - acc: 0.9314 - val_loss: 0.4736 - val_acc: 0.9107
#
# Epoch 00004: val_acc did not improve from 0.94048
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 5/50
# 56/56 [==============================] - 70s 1s/step - loss: 0.1018 - acc: 0.9604 - val_loss: 0.1995 - val_acc: 0.9345
#
# Epoch 00005: val_acc did not improve from 0.94048
# Epoch 6/50
# 43/56 [======================>.......] - ETA: 16s - loss: 0.0807 - acc: 0.9724
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b7ecd43c84bf> in <module>
#      10     print('### %s:' % exp)
#      11     H5FILE = H5FILE_FORMAT % exp
# ---> 12     exps[exp] = train(EPOCHS, ALPHA, H5FILE, BATCH_SIZE)
#      13     print('###end %s:' % exp)
#      14     print()
#
# <ipython-input-7-6948d410842a> in train(EPOCHS, ALPHA, H5FILE, BATCH_SIZE)
#      35         callbacks=callbacks,
#      36         epochs=EPOCHS,
# ---> 37         verbose=1
#      38     )
#      39     return history
#
# /opt/conda/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
plot_train_history(exps, EPOCHS)

# %%
for exp in exps.keys():
    print('### %s:' % exp)
    H5FILE = H5FILE_FORMAT % exp
    model = keras.models.load_model(H5FILE)
    predict_val = model.predict_generator(get_val_gen(df_val, BATCH_SIZE), steps=np.ceil(df_val.shape[0]/BATCH_SIZE))
    make_validation(df_val['category'].replace(label_map).to_numpy(), predict_val, label_map[PREDICT_CATEGORY])
    predict_test = model.predict_generator(
        get_test_gen(df_test, BATCH_SIZE), 
        steps=np.ceil(df_test.shape[0]/BATCH_SIZE))
    df_out = pd.DataFrame()
    df_out['ID'] = df_test['filename'].apply(lambda fn: fn.split('.')[0])
    df_out['Predicted'] = predict_test[:, label_map[PREDICT_CATEGORY]]
    df_out.to_csv(OUTFILE_FORMAT % exp, index=False)
    print()
# Out:
# ### e050_a035:
# Found 400 images belonging to 2 classes.
# Validation AUC: 0.537, Accuracy: 0.487
# Found 400 images.
